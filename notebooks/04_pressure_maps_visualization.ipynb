# %%
"""
Скрипт предназначен для визуализации распределения давления на фасаде здания
по данным из аэродинамического эксперимента.

Входные данные:
- CSV-файл с координатами точек на фасаде (X, Y)
- Значения давления (например, Cp или P) для каждой точки

Задача:
1. Загрузить и очистить данные
2. Построить тепловую карту давления:
    - по X и Y координатам
    - с интерполяцией значений
3. Сохранить набор изображений в папке

Цель визуализации:
- Выявить распределение давления по фасаду
- Использовать график как основу для дальнейшего анализа/моделирования

Примечание:
- Поддерживается настройка шага интерполяции и цветовой схемы
- При необходимости можно отфильтровать точки по углу ветра или сценарию
"""

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# Путь к файлу (если скрипт и CSV в одной папке, путь можно оставить простым)
file_path = '/mnt/d/projects/wind_pressure_prediction_2025/data/processed/WindLoading_Interference_01.csv'
df = pd.read_csv(file_path)

# Папка для сохранения графиков
output_dir = '/mnt/d/projects/wind_pressure_prediction_2025/results/figures/facade_pressure_maps'
os.makedirs(output_dir, exist_ok=True)

# Значение фильтрации по Lwr
lwr_value = 1
int_values = df['Int_Pnt'].unique()
ang_values = df['Ang'].unique()

# 🔥 Функция построения карты давления
def plot_pressure_map_ax(data, value_col, title_suffix, cmap_name, ax):
    pivot = data.pivot_table(index='Y_fac', columns='X_fac', values=value_col)

    """
    # 🎯 Устанавливаем фиксированный масштаб цветовой шкалы
    if value_col == 'Mean':
        vmin, vmax = -1.4, 1.4
        ticks = np.linspace(vmin, vmax, 5)  # шаг = 0.7
    elif value_col == 'StdDev':
        vmin, vmax = 0, 0.6
        ticks = np.linspace(vmin, vmax, 7)  # шаг = 0.1
    else:
        vmin = vmax = None
    """

    # 🎯 Не задаём принудительные границы — пусть выбирает автоматически
    vmin = vmax = None
    cbar_kws = {}  # пустой словарь

    """sns.heatmap(pivot, cmap=cmap_name, annot=False, ax=ax, cbar=True, vmin=vmin, vmax=vmax, cbar_kws={'ticks': ticks})"""

    sns.heatmap(pivot, cmap=cmap_name, annot=False, ax=ax, cbar=True, vmin=vmin, vmax=vmax, cbar_kws=cbar_kws)

    ax.set_title(title_suffix)
    ax.set_xlabel("x facade")
    ax.set_ylabel("y facade")
    ax.invert_yaxis()
    ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=6)
    ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=6)

    # ➕ Добавим вертикальные разделители между фасадами
    for x in [7, 14, 21]:  # середина между 7-8, 14-15, 21-22
        ax.axvline(x=x, color='black', linestyle='--', linewidth=1)

# Перебираем все комбинации
for int_pnt in int_values:
    for ang in ang_values:
        filtered = df[(df['Lwr'] == lwr_value) & (df['Int_Pnt'] == int_pnt) & (df['Ang'] == ang)]
        
        if filtered.empty:
            continue

        print(f"Обрабатываем: Lwr={lwr_value}, Int_Pnt={int_pnt}, Ang={ang}, точек: {filtered.shape[0]}")

        # 🎨 Создаём фигуру с двумя subplot'ами
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
        plot_pressure_map_ax(filtered, 'Mean', 'Cp', 'coolwarm', ax1)
        plot_pressure_map_ax(filtered, 'StdDev', 'σ', 'YlGnBu', ax2)
        plt.tight_layout()

        # 📁 Сохраняем файл
        filename = f"Lwr{lwr_value}_Int{int_pnt}_Ang{ang}.png"
        filepath = os.path.join(output_dir, filename)
        plt.savefig(filepath, dpi=300)
        plt.close()
# Out:
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=1, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=10, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=11, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=12, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=14, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=15, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=16, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=17, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=19, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=2, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=20, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=22, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=23, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=24, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=25, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=27, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=29, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=3, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=30, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=31, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=32, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=33, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=35, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=36, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=37, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=38, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=4, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=5, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=6, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=7, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=8, Ang=180, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=0, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=10, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=20, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=30, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=40, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=50, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=60, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=70, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=80, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=90, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=100, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=110, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=120, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=130, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=140, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=150, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=160, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=170, точек: 252
# Обрабатываем: Lwr=1, Int_Pnt=9, Ang=180, точек: 252
